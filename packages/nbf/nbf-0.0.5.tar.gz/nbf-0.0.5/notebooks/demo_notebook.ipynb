# %% [markdown]
# # Feature:
# Show off notebooks-as-features system.
# [epc notebook](https://colab.research.google.com/drive/14SkCL1Vgr9lIZ0u87U8tDVK-KOk4aHYs)

# %%
import os

if 'c' not in globals():
  c={'resources':{'jai':{}},'use_google_drive':False}
  # !wget -qO epc.py https://maya.software/epc.txt
  import epc
  c = epc.do_setup(c)
  logger = epc.get_logger('demo')
  # %run {c.get('nb_dir')}notebooks_as_features.ipynb

if os.path.isdir(c['project_path']+'/.git'): 
  os.system(f"{c['project_path']} && git pull")
# Out:
# 2023-01-18 17:32:07 epc INFO     epc.config_dict(c): may be overridden by `c[setting_name]`
# 2023-01-18 08:32:07 epc INFO     log_level: DEBUG
# 2023-01-18 08:32:07 epc INFO     timezone: America/Anchorage
# 2023-01-18 08:32:07 epc INFO     use_google_drive: False
# 2023-01-18 08:32:07 epc INFO     epc: ...
# 2023-01-18 08:32:07 epc INFO     resources: {'jai': {}}
# 2023-01-18 08:32:07 epc INFO     setup_commands: []
# 2023-01-18 08:32:07 epc INFO     active_project: jai
# 2023-01-18 08:32:07 epc INFO     projects_dir: /content/
# 2023-01-18 08:32:07 epc INFO     project_path: /content/jai/
# 2023-01-18 08:32:07 epc INFO     nb_dir: /content/jai/notebooks/
# 2023-01-18 08:32:07 epc WARNING  Resource exists: /content/jai

# %%
c

# %%
# %pip install sphinx

# %%
rez = epc.make_request('huggingface',{'model':'mrm8488/t5-base-finetuned-common_gen','inputs':'"plant ground hole"'},'huggingface')

# if 'error' in rez:
#   print('err!')
# if json.loads(rez)
# facebook/bart-large-mnli

# %%
# # %%from_template first_cell
# try:
#   c
# except:
#   c = {'github':['jai'],'use_google_drive':False}
#   !wget -qO epc.py https://maya.software/epc.txt
#   import epc
#   c = epc.load_requests(c)
#   %run {c.get('nb_dir')}setup_project.ipynb

# if epc.os.path.isdir(c['projects_dir']+c['active_project']+'/.git'):
#   !cd {c['projects_dir']}{c['active_project']} && git pull

# %%
c

# %%
# epc.decode(c['epc']).keys()

# %%
# %macro
# %hist

# %%
# epc.__e
# dir(epc)
# [item for item in dir(epc) if not item.startswith("__")]
# epc.__e = {}

# %%
def config_dict():
  # @title Test Form
  Name = 'John Doe'    # @param {type: "string"}
  Age = 42    # @param {type: "integer"}
  return locals()

print(config_dict())

# %%
# it works! It also overwrites c['epc']
# from epc import encode
# encode({'the':'cat','in':'hat'})

# %%
# !ls -la ~/.cache

# %% [markdown]
# # EOF

# %% [markdown]
# ## Git

# %%
if c['running_nb'] == c['nb_name']: run_nb('git_for_colab')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-763bf67048a4> in <module>
# ----> 1 if c['running_nb'] == c['nb_name']: run_nb('git_for_colab')
#
# NameError: name 'c' is not defined

# %%
#@title Git Commit Message { run: "auto", vertical-output: true }
commit_message = "" #@param {type:"string"}
commit_message = c.get('commit_message','colab')+commit_message
print(commit_message)

# %%
# %%from_template git
# #@title Git Actions { run: "auto", vertical-output: true }
# if c['running_nb'] == c['nb_name']:
#   github_index = 0 #@param ["0", "1", "2"] {type:"raw"}
#   git_action = "nb2repo*" #@param ["","nb2repo*","pull","diff","diff origin --minimal","git_nbastatus*","commit -m {message}","push","ppush*","status","fetch","merge","push origin dev","diff main dev","merge main","merge dev","checkout main","checkout dev","diff --staged","restore","add .","branch -a","log -15 --graph --oneline --decorate","reset --hard HEAD","reset --hard HEAD~1","commit --amend -m {messaage}"]
#
#   print('repo indices: '+str(dict(zip(range(len(c['github'])),c['github']))))
#   if github_index > len(c['github'])-1:
#     print('no repo at that index')
#   else:
#     print('repo:',c['github'][github_index])
#   if git_action!='':
#     if git_action=='nb2repo*': nb2repo()
#     elif git_action=='ppush*': git_ppush(commit_message)
#     elif git_action=='git_nbastatus*': git_nbastatus(github_index)
#     else:
#       if git_action=="commit -m {message}": git_action = f"commit -m '{commit_message}'"
#       if git_action=="commit --amend -m {messaage}": git_action = f"commit --amend -m '{commit_message}'"
#       !cd {c['github'][github_index]} && git {git_action}

# %%
# if c['run_nb'] == c['nb_name']: git_ppush('colab')
